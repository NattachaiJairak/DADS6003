# %% [markdown]
# <a href="https://colab.research.google.com/github/NattachaiJairak/DADS6003/blob/main/Lab2%20by%20Tum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.1 Normal equation (Numpy version)

# %%
import numpy as np
np.set_printoptions(precision=3)

x = np.array([0,2,3])
y = np.array([1,1,4])
x_b = np.c_[np.ones((len(x),1)),x]

#call inverse function from linear algebra module
theta = np.linalg.pinv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
print(type(theta))
print("theta = ", theta)

#prediction
x_t = np.array([0,2,3])
x_t_b = np.c_[np.ones((len(x_t),1)), x_t]
y_p = x_t_b.dot(theta)
print("x_test = ",x_t)
print("y predict = ",y_p)

import matplotlib.pyplot as plt
plt.title("y = "+str(np.round(theta[0],2))+"+"+str(np.round(theta[1],2))+r"$x_1$")
plt.plot(x_t, y_p,"r.-")
plt.plot(x, y, "b+")
for x,y in zip(x_t, y_p):
  plt.text( x ,y, f"({np.round(x,2)} , {np.round(y,2)})")
plt.axis([0,10,0,10])
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# theta =  [0.571 0.857]
# x_test =  [0 2 3]
# y predict =  [0.571 2.286 3.143]

# %% [markdown]
# ## 1.2 Normal equation (Sklearn version)

# %%
from IPython.display import display, Latex
from sklearn.linear_model import LinearRegression
x = np.array([[0,2,3]]).T
y = np.array([1,1,4])

lin_reg = LinearRegression()
lin_reg.fit(x, y)
display(Latex(f'$y = {np.round(lin_reg.intercept_,2)}+{np.round(lin_reg.coef_[0],2)}x_{1}$'))
x_n = np.array([[1,5]]).T
ans = lin_reg.predict(x_n)
print("Predicted results = ")
print(ans)
# Out:
# $y = 0.57+0.86x_1$
# Predicted results =
# [1.429 4.857]

# %% [markdown]
# #2. Gradient descent

# %%
import random

# %%
#Relation between key=theta, value=J
lossTheta0 = {}
lossTheta1 = {}

# %%
def cost_function(theta0, theta1, x, y, N):
    c = 1/(2*N) * sum([(theta0 + theta1*x[i] - y[i])**2 for i in range(N)])
    return c

# %%
def gradient_descent(alpha, x, y, ep=0.001, max_iter=10000):
  converged = False
  iter = 0
  N = x.shape[0] # number of samples

  # initial theta
  t0 = np.random.random(x.shape[1])
  print("Initial theta0 ",t0)

  t1 = np.random.random(x.shape[1])
  print("Initial theta1",t1)

  # total error, J(theta)
  J = cost_function(t0,t1,x,y,N)
  print("First J = ",J)

  lossTheta0[t0[0]] = J[0]
  lossTheta1[t1[0]] = J[0]

  # Iterate Loop
  while not converged:
    grad0 = sum([(t0 + t1*x[i] - y[i])*1 for i in range(N)])
    grad1 = sum([(t0 + t1*x[i] - y[i])*x[i] for i in range(N)])

    # update the theta_temp
    t0 = t0 - alpha * (1/N) * grad0
    t1 = t1 - alpha * (1/N) * grad1

    #print("\niter = ",iter)
    #print("t0 = ",t0)
    #print("t1 = ",t1)
    # error
    e = cost_function(t0,t1,x,y,N)
    print("error = ",e)

    #Terminate 1
    if abs(J-e) <= ep:
        print("Converged at ", iter, "/", max_iter)
        converged = True

    J = e   # update error s
    iter += 1  # update iter

    if iter % 1 == 0:
      lossTheta0[t0[0]] = J[0]
      lossTheta1[t1[0]] = J[0]

    #Termiate 2
    if iter == max_iter:
        print('Max interactions exceeded!')
        converged = True

  return np.array([t0,t1]).reshape(-1)

# %%
if __name__ == '__main__':

  x = np.array([[0,2,3]]).T # or x = np.array([[0],[2],[3]])
  y = np.array([1,1,4])
  print("x.shape = %s y.shape = %s" %(x.shape, y.shape))
  alpha = 0.01 # learning rate

  theta = gradient_descent(alpha, x, y,ep=0.0000000001, max_iter=100000)
  print(type(theta))
  print (theta)


  #prediction
  x_t = range(0,11)
  x_t_b = np.c_[np.ones((len(x_t),1)), x_t]
  y_p = x_t_b.dot(theta)
  #print("x_test = ",x_t)
  #print("y predict = ",y_p)

  # plot
  plt.title("y = "+str(np.round(theta[0],2))+"+"+str(np.round(theta[1],2))+r"$x_1$")
  plt.plot(x_t, y_p,"r.-")
  plt.plot(x, y, "b.",marker="+")
  for x,y in zip(x_t, y_p):
    plt.text( x ,y, f"({np.round(x,2)} , {np.round(y,2)})")
  plt.axis([0,10,0,10])
  plt.xlabel(r'$x$')
  plt.ylabel(r'$y$')
  plt.show()
# Out:
# x.shape = (3, 1) y.shape = (3,)
# Initial theta0  [0.221]
# Initial theta1 [0.579]
# First J =  [0.82]
# error =  [0.782]
# error =  [0.748]
# error =  [0.717]
# error =  [0.69]
# error =  [0.665]
# error =  [0.642]
# error =  [0.622]
# error =  [0.604]
# error =  [0.587]
# error =  [0.572]
# error =  [0.559]
# error =  [0.547]
# error =  [0.536]
# error =  [0.526]
# error =  [0.517]
# error =  [0.509]
# error =  [0.502]
# error =  [0.495]
# error =  [0.489]
# error =  [0.484]
# error =  [0.479]
# error =  [0.475]
# error =  [0.471]
# error =  [0.467]
# error =  [0.464]
# error =  [0.461]
# error =  [0.459]
# error =  [0.456]
# error =  [0.454]
# error =  [0.452]
# error =  [0.45]
# error =  [0.449]
# error =  [0.447]
# error =  [0.446]
# error =  [0.445]
# error =  [0.444]
# error =  [0.443]
# error =  [0.442]
# error =  [0.441]
# error =  [0.441]
# error =  [0.44]
# error =  [0.439]
# error =  [0.439]
# error =  [0.438]
# error =  [0.438]
# error =  [0.437]
# error =  [0.437]
# error =  [0.437]
# error =  [0.436]
# error =  [0.436]
# error =  [0.436]
# error =  [0.436]
# error =  [0.435]
# error =  [0.435]
# error =  [0.435]
# error =  [0.435]
# error =  [0.435]
# error =  [0.435]
# error =  [0.435]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.434]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.433]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.432]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.431]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.43]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# error =  [0.429]
# Converged at  2101 / 100000
# <class 'numpy.ndarray'>
# [0.571 0.857]
# <ipython-input-73-17018a97f73b>:23: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "b." (-> marker='.'). The keyword argument will take precedence.

# %%
y_p
# Out:
# array([0.571, 2.286, 3.143])

# %%
y
# Out:
# array([1, 1, 4])

# %%
# Calculate the squared differences between predicted and actual values
squared_differences = (y_p - y)**2

# Calculate the mean of the squared differences
mse = np.mean(squared_differences)

# Print the MSE
print("MSE:", mse)
# Out:
# MSE: 0.8571428571428568

# %% [markdown]
# #Gradient Descent curve Static VS Dynamic

# %%
lists = sorted(lossTheta0.items()) # sorted by key, return a list of tuples
numPoints = len(lists)
print(numPoints)
_x, _y = zip(*lists) # unpack a list of pairs into two tuples
plt.scatter(range(numPoints),_y)
plt.xticks(range(0,numPoints,10))
plt.xlabel(r'$Iteration$')
plt.ylabel(r'$Cost value (J)$')
# Out:
# 1001
# Text(0, 0.5, '$Cost value (J)$')

# %%
import plotly.graph_objects as go
import numpy as np

_x = list(_x)
_y = list(_y)
xm = np.min(_x) - 0.2
xM = np.max(_x) + 0.2
ym = np.min(_y) - 0.2
yM = np.max(_y) + 0.2
N = len(_x)

# Create figure
fig = go.Figure(
    data=[go.Scatter(x=_x, y=_y,
                     mode="lines",
                     line=dict(width=2, color="blue")),
          go.Scatter(x=_x, y=_y,
                     mode="lines",
                     line=dict(width=2, color="blue"))],

    layout=go.Layout(

        xaxis=dict(range=[xm, xM]),
        yaxis=dict(range=[ym, yM]),

        title_text="Gradient Descent",
        hovermode="closest",
        xaxis_title=r"$\theta_0$",
        yaxis_title="Cost function (J)",

        updatemenus=[
            dict(type="buttons",
                          buttons=[dict(label="Click to play",
                                        method="animate",
                                        args=[None])]
                 )
            ]
        ),

    frames=[go.Frame(
        data=[go.Scatter(
            x=[_x[k]],
            y=[_y[k]],
            mode="markers",
            marker=dict(color="red", size=10))])
        for k in range(0,N,5)],
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="05abd855-4779-402b-aabb-473dc32008c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("05abd855-4779-402b-aabb-473dc32008c5")) {                    Plotly.newPlot(                        "05abd855-4779-402b-aabb-473dc32008c5",                        [{"line":{"color":"blue","width":2},"mode":"lines","x":[0.11005938174089214,0.12312820103911946,0.13557178518205942,0.14742144711721428,0.15870692702702144,0.169456471338754,0.17969690776521216,0.18945371657560653,0.1987510982860164,0.20761203794929262,0.21605836621523852,0.22411081732331964,0.23178908418200295,0.23911187068108397,0.2460969413760079,0.25276116867620774,0.2591205776628495,0.2651903886550763,0.2709850576378591,0.2765183146588804,0.2818032002964813,0.2868521002955744,0.2916767784635586,0.2962884079136488,0.3006976007386398,0.30491443619395586,0.3089484874648735,0.3128088470890454,0.31650415110187796,0.3200426019689234,0.3234319903662217,0.32667971586646893,0.3297928065859793,0.3327779378446477,0.335641449888496,0.3383893647218965,0.3410274020941997,0.3435609946832455,0.34599530251610533,0.34833522666537303,0.35058542225739947,0.35275031082703656,0.3548340920517197,0.3568407548960688,0.3587740881966224,0.36063769071482926,0.3624349806850123,0.36416920488267435,0.36584344723724344,0.36746063701214265,0.36902355657392144,0.3705348487710924,0.37199702394228046,0.3734124665723075,0.3747834416138976,0.37611210049180277,0.3774004868053019,0.37865054174422685,0.3798641092329061,0.3810429408156955,0.38218870029707774,0.3833029681486594,0.3843872456947771,0.3854429590878343,0.3864714630839315,0.3874740446288232,0.3884519262637298,0.38940626936005474,0.3903381771916013,0.3912486978524538,0.39213882702827546,0.39300951062838735,0.39386164728562223,0.3946960907305957,0.39551365204670397,0.3963151018118395,0.39710117213251606,0.397872558575808,0.39862992200423714,0.3993738903184827,0.4001050601125456,0.4008239982457645,0.4015312433358609,0.4022273071769806,0.4029126760864994,0.4035878121841719,0.40425315460702177,0.4049091206632021,0.40555610692789174,0.4061944902841392,0.4068246289114202,0.4074468632245353,0.4080615167653426,0.40866889704969406,0.40926929637182774,0.409862992568351,0.4104502497438463,0.4110313189600268,0.4116064388902731,0.4121758364412902,0.4127397273435368,0.41329831671199496,0.4138517995787708,0.41440036139894115,0.4149441785309902,0.41548341869311234,0.41601824139659427,0.4165487983574271,0.4170752338872427,0.41759768526461255,0.4181162830876958,0.4186311516091734,0.41914240905435857,0.419650167923328,0.4201545352778773,0.4206556130140625,0.4211534981210524,0.4216482829269784,0.42214005533243626,0.4226288990322588,0.4231148937261502,0.42359811531874014,0.4240786361095901,0.4245565249736563,0.4250318475326886,0.425504666318021,0.4259750409251861,0.4264430281607641,0.42690868218185624,0.427372054628554,0.4278331947497551,0.4282921495226611,0.42874896376627325,0.4292036802491892,0.42965633979198603,0.43010698136446157,0.430555642177993,0.4310023577732572,0.4314471621035462,0.4318900876138996,0.4323311653162624,0.4327704248608704,0.4332078946040501,0.43364360167261523,0.43407757202502956,0.4345098305094994,0.43494040091914915,0.43536930604442725,0.43579656772288083,0.4362222068864322,0.43664624360628174,0.43706869713555696,0.43748958594982096,0.4379089277855476,0.43832673967666547,0.4387430379892682,0.43915783845458245,0.4395711562002816,0.4399830057802283,0.44039340120272447,0.4408023559573439,0.4412098830404188,0.4416159949792474,0.4420207038550878,0.4424240213249977,0.4428259586425794,0.4432265266776839,0.4436257359351274,0.4440235965724684,0.4444201184168947,0.44481531098126253,0.4452091834793326,0.4456017448402418,0.44599300372225015,0.4463829685257985 ...
