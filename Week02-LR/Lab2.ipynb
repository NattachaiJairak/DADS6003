# %% [markdown]
# <a href="https://colab.research.google.com/github/NattachaiJairak/DADS6003/blob/main/Week02-LR/Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1.1 Normal equation (Numpy version)

# %%
import numpy as np
np.set_printoptions(precision=3)

x = np.array([0,2,3])
y = np.array([1,1,4])
x_b = np.c_[np.ones((len(x),1)),x]

#call inverse function from linear algebra module
theta = np.linalg.pinv(x_b.T.dot(x_b)).dot(x_b.T).dot(y)
print(type(theta))
print("theta = ", theta)

#prediction
x_t = range(0,11)
x_t_b = np.c_[np.ones((len(x_t),1)), x_t]
y_p = x_t_b.dot(theta)
print("x_test = ",x_t)
print("y predict = ",y_p)

import matplotlib.pyplot as plt
plt.title("y = "+str(np.round(theta[0],2))+"+"+str(np.round(theta[1],2))+r"$x_1$")
plt.plot(x_t, y_p,"r.-")
plt.plot(x, y, "b+")
for x,y in zip(x_t, y_p):
  plt.text( x ,y, f"({np.round(x,2)} , {np.round(y,2)})")
plt.axis([0,10,0,10])
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.show()
# Out:
# <class 'numpy.ndarray'>
# theta =  [0.571 0.857]
# x_test =  range(0, 11)
# y predict =  [0.571 1.429 2.286 3.143 4.    4.857 5.714 6.571 7.429 8.286 9.143]

# %% [markdown]
# ## 1.2 Normal equation (Sklearn version)

# %%
from IPython.display import display, Latex
from sklearn.linear_model import LinearRegression
x = np.array([[0,2,3]]).T
y = np.array([1,1,4])

lin_reg = LinearRegression()
lin_reg.fit(x, y)
display(Latex(f'$y = {np.round(lin_reg.intercept_,2)}+{np.round(lin_reg.coef_[0],2)}x_{1}$'))
x_n = np.array([[1,5]]).T
ans = lin_reg.predict(x_n)
print("Predicted results = ")
print(ans)
# Out:
# $y = 0.57+0.86x_1$
# Predicted results =
# [1.429 4.857]

# %% [markdown]
# #2. Gradient descent

# %%
import random

# %%
#Relation between key=theta, value=J
lossTheta0 = {}
lossTheta1 = {}

# %%
def cost_function(theta0, theta1, x, y, N):
    c = 1/(2*N) * sum([(theta0 + theta1*x[i] - y[i])**2 for i in range(N)])
    return c

# %%
def gradient_descent(alpha, x, y, ep=0.001, max_iter=10000):
  converged = False
  iter = 0
  N = x.shape[0] # number of samples

  # initial theta
  t0 = np.random.random(x.shape[1])
  print("Initial theta0 ",t0)

  t1 = np.random.random(x.shape[1])
  print("Initial theta1",t1)

  # total error, J(theta)
  J = cost_function(t0,t1,x,y,N)
  print("First J = ",J)

  lossTheta0[t0[0]] = J[0]
  lossTheta1[t1[0]] = J[0]

  # Iterate Loop
  while not converged:
    grad0 = sum([(t0 + t1*x[i] - y[i])*1 for i in range(N)])
    grad1 = sum([(t0 + t1*x[i] - y[i])*x[i] for i in range(N)])

    # update the theta_temp
    t0 = t0 - alpha * (1/N) * grad0
    t1 = t1 - alpha * (1/N) * grad1

    #print("\niter = ",iter)
    #print("t0 = ",t0)
    #print("t1 = ",t1)
    # error
    e = cost_function(t0,t1,x,y,N)
    #print("error = ",e)

    #Terminate 1
    if abs(J-e) <= ep:
        print("Converged at ", iter, "/", max_iter)
        converged = True

    J = e   # update error s
    iter += 1  # update iter

    if iter % 1 == 0:
      lossTheta0[t0[0]] = J[0]
      lossTheta1[t1[0]] = J[0]

    #Termiate 2
    if iter == max_iter:
        print('Max interactions exceeded!')
        converged = True

  return np.array([t0,t1]).reshape(-1)

# %%
if __name__ == '__main__':

  x = np.array([[0,2,3]]).T # or x = np.array([[0],[2],[3]])
  y = np.array([1,1,4])
  print("x.shape = %s y.shape = %s" %(x.shape, y.shape))
  alpha = 0.01 # learning rate

  theta = gradient_descent(alpha, x, y,ep=0.0000000001, max_iter=1000)
  print(type(theta))
  print (theta)


  #prediction
  x_t = range(0,11)
  x_t_b = np.c_[np.ones((len(x_t),1)), x_t]
  y_p = x_t_b.dot(theta)
  #print("x_test = ",x_t)
  #print("y predict = ",y_p)

  # plot
  plt.title("y = "+str(np.round(theta[0],2))+"+"+str(np.round(theta[1],2))+r"$x_1$")
  plt.plot(x_t, y_p,"r.-")
  plt.plot(x, y, "b.",marker="+")
  for x,y in zip(x_t, y_p):
    plt.text( x ,y, f"({np.round(x,2)} , {np.round(y,2)})")
  plt.axis([0,10,0,10])
  plt.xlabel(r'$x$')
  plt.ylabel(r'$y$')
  plt.show()
# Out:
# x.shape = (3, 1) y.shape = (3,)
# Initial theta0  [0.27]
# Initial theta1 [0.397]
# First J =  [1.165]
# Max interactions exceeded!
# <class 'numpy.ndarray'>
# [0.567 0.859]
# <ipython-input-16-f00e9816204d>:23: UserWarning:
#
# marker is redundantly defined by the 'marker' keyword argument and the fmt string "b." (-> marker='.'). The keyword argument will take precedence.

# %% [markdown]
# #Gradient Descent curve Static VS Dynamic

# %%
lists = sorted(lossTheta0.items()) # sorted by key, return a list of tuples
numPoints = len(lists)
print(numPoints)
_x, _y = zip(*lists) # unpack a list of pairs into two tuples
plt.scatter(range(numPoints),_y)
plt.xticks(range(0,numPoints,10))
plt.xlabel(r'$Iteration$')
plt.ylabel(r'$Cost value (J)$')
# Out:
# 1001
# Text(0, 0.5, '$Cost value (J)$')

# %%
import plotly.graph_objects as go
import numpy as np

_x = list(_x)
_y = list(_y)
xm = np.min(_x) - 0.2
xM = np.max(_x) + 0.2
ym = np.min(_y) - 0.2
yM = np.max(_y) + 0.2
N = len(_x)

# Create figure
fig = go.Figure(
    data=[go.Scatter(x=_x, y=_y,
                     mode="lines",
                     line=dict(width=2, color="blue")),
          go.Scatter(x=_x, y=_y,
                     mode="lines",
                     line=dict(width=2, color="blue"))],

    layout=go.Layout(

        xaxis=dict(range=[xm, xM]),
        yaxis=dict(range=[ym, yM]),

        title_text="Gradient Descent",
        hovermode="closest",
        xaxis_title=r"$\theta_0$",
        yaxis_title="Cost function (J)",

        updatemenus=[
            dict(type="buttons",
                          buttons=[dict(label="Click to play",
                                        method="animate",
                                        args=[None])]
                 )
            ]
        ),

    frames=[go.Frame(
        data=[go.Scatter(
            x=[_x[k]],
            y=[_y[k]],
            mode="markers",
            marker=dict(color="red", size=10))])
        for k in range(0,N,5)],
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="460d0e0e-4392-40b1-805c-41482c6086de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("460d0e0e-4392-40b1-805c-41482c6086de")) {                    Plotly.newPlot(                        "460d0e0e-4392-40b1-805c-41482c6086de",                        [{"line":{"color":"blue","width":2},"mode":"lines","x":[0.27014984098951145,0.2808377385983996,0.2910024805817709,0.30067030601113603,0.3098661359206223,0.3186136395206675,0.3269352970853449,0.3348524596804252,0.34238540589088795,0.34955339569862015,0.35637472165346806,0.3628667574736154,0.369046004204431,0.37492813405844055,0.3805280320529156,0.3858598355557206,0.39093697184450116,0.39577219377901585,0.40037761368140284,0.404764735514408,0.4089444854430802,0.41292724086114324,0.41672285795917396,0.42034069790784245,0.4237896517257883,0.42707816389821357,0.43021425480895215,0.4332055420456227,0.43605926063447836,0.4387822822587213,0.44138113351135033,0.44386201323104335,0.44623080896713985,0.44849311261747526,0.45065423528062015,0.45271922136199017,0.4546928619713101,0.4565797076470322,0.4583840804415203,0.4601100853991128,0.461761621457565,0.46334239180183767,0.46485591369774465,0.46630552783158963,0.4676944071806099,0.4690255654377975,0.47030186501348475,0.4715260246349562,0.47270062656428036,0.4738281234535418,0.4749108448556882,0.475951003408294,0.47695070070667217,0.47791193288194,0.4788365958988614,0.47972649058754313,0.4805833274223553,0.48140873106077503,0.48220424465421335,0.48297133394228103,0.48371139114137224,0.4844257386378987,0.4851156324959884,0.4857822657889696,0.48642677176349247,0.48705022684469584,0.4876536534904051,0.4882380229019452,0.4888042575987713,0.4893532338637597,0.4898857840656555,0.4904026988648493,0.49090472930834245,0.49139258881947034,0.4918669550876679,0.4923284718633008,0.49277775066233076,0.4932153723853448,0.4936418888552506,0.49405782427772377,0.4944636766282875,0.4948599189697113,0.49524700070322814,0.4956253487568954,0.4959953687142577,0.49635744588630965,0.4967119463296077,0.4970592178132364,0.49739959073719814,0.49773337900466647,0.4980608808504218,0.4983823796276695,0.4986981445553317,0.49900843142779866,0.4993134832890255,0.49961353107276474,0.49990879421063744,0.5001994812096567,0.50048579020074,0.5007679094596662,0.5010460179018629,0.5013202855523375,0.5015908739920022,0.5018579367815765,0.5021216198641971,0.5023820619478008,0.5026393948683,0.5028937439345141,0.5031452282557728,0.5033939610530634,0.5036400499545477,0.5038835972762334,0.5041247002885474,0.5043634514695172,0.5045999387452349,0.5048342457182413,0.5050664518844381,0.5052966328391038,0.5055248604725607,0.505751203156014,0.505975725918054,0.5061984906122942,0.5064195560765877,0.5066389782842459,0.5068568104876615,0.5070731033547174,0.5072879050983434,0.5075012615995652,0.5077132165243733,0.5079238114347205,0.5081330858939455,0.5083410775668996,0.508547822315046,0.5087533542867809,0.5089577060032188,0.5091609084396687,0.5093629911030184,0.5095639821052322,0.5097639082331564,0.5099627950148194,0.5101606667824019,0.5103575467320444,0.5105534569806508,0.51074841861984,0.5109424517671866,0.5111355756148893,0.5113278084759952,0.5115191678283021,0.5117096703560563,0.511899331989557,0.5120881679427711,0.5122761927490599,0.512463420295111,0.5126498638531675,0.5128355361116371,0.5130204492041668,0.5132046147372553,0.5133880438164807,0.5135707470714105,0.5137527346792614,0.5139340163873715,0.5141146015345432,0.5142944990713167,0.5144737175792237,0.5146522652890756,0.5148301500983341,0.5150073795876094,0.5151839610363304,0.5153599014376281,0.5155352075124732,0.515709885723103,0.5158839422857749,0.5160573831828809,0.5162302141744523,0.5164024408090891,0.5165740684343405,0.516745102 ...
